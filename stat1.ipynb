# %%
d = [i for i in range(100)]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# sns.set(
#     font_scale = 2,
#     style = "whitegrid",
#     rc = {"figure.figsize" : (20,10)}
# )

# %%
np.std(d, ddof=1).round(3)
# Out:
# 29.011

# %%
df = pd.read_csv("/mnt/HC_Volume_18315164/home-jupyter/jupyter-an-bogdanov/games.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.Year.describe()
# Out:
# count    16291.000000
# mean      2006.405561
# std          5.832412
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %%
df.Year.value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
sns.countplot(df.Year)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.Platform.value_counts(normalize=True) * 100
# Out:
# DS      13.080842
# PS2     13.056289
# PS3      8.004420
# Wii      7.918483
# X360     7.574735
# PSP      7.347615
# PS       7.298508
# PC       5.757780
# XB       4.929102
# GBA      4.824750
# GC       3.326990
# 3DS      3.063041
# PSV      2.516727
# PS4      2.062488
# N64      1.939721
# SNES     1.467068
# XOne     1.307470
# SAT      1.061936
# WiiU     0.877785
# 2600     0.712050
# NES      0.601559
# GB       0.595421
# DC       0.319195
# GEN      0.165736
# NG       0.073660
# SCD      0.036830
# WS       0.036830
# 3DO      0.018415
# TG16     0.012277
# PCFX     0.006138
# GG       0.006138
# Name: Platform, dtype: float64

# %%
df.groupby("Platform", as_index=False) \
    .agg({"Rank" : "count"}).sort_values("Rank", ascending=False)
# Out:
#    Platform  Rank
# 4        DS  2131
# 16      PS2  2127
# 17      PS3  1304
# 26      Wii  1290
# 28     X360  1234
# 19      PSP  1197
# 15       PS  1189
# 13       PC   938
# 29       XB   803
# 6       GBA   786
# 7        GC   542
# 2       3DS   499
# 20      PSV   410
# 18      PS4   336
# 10      N64   316
# 23     SNES   239
# 30     XOne   213
# 21      SAT   173
# 27     WiiU   143
# 0      2600   116
# 11      NES    98
# 5        GB    97
# 3        DC    52
# 8       GEN    27
# 12       NG    12
# 22      SCD     6
# 25       WS     6
# 1       3DO     3
# 24     TG16     2
# 14     PCFX     1
# 9        GG     1

# %%
df.Publisher.value_counts()
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# New World Computing                1
# 989 Sports                         1
# Rain Games                         1
# Ongakukan                          1
# Berkeley                           1
# Name: Publisher, Length: 576, dtype: int64

# %%
df_nintendo = df.query("Publisher == 'Nintendo'")

# %%
df_nintendo
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_nintendo.NA_Sales.quantile(q=0.5)
# Out:
# 0.375

# %%
df_nintendo.EU_Sales.quantile(q=0.5)
# Out:
# 0.12

# %%
df_nintendo.JP_Sales.quantile(q=0.5)
# Out:
# 0.28

# %%
df_nintendo.Other_Sales.quantile(q=0.5)
# Out:
# 0.03

# %%
plt.figure(figsize=(23,16))
sns.boxplot(x = "Genre", y = "JP_Sales", data = df_nintendo)

# %%
df_nintendo.groupby("Genre", as_index = False) \
    .agg({"JP_Sales" : "median"}).sort_values("JP_Sales", ascending=False)
# Out:
#            Genre  JP_Sales
# 4       Platform     0.540
# 2       Fighting     0.500
# 9     Simulation     0.390
# 7   Role-Playing     0.360
# 6         Racing     0.340
# 5         Puzzle     0.255
# 3           Misc     0.250
# 10        Sports     0.250
# 11      Strategy     0.190
# 0         Action     0.170
# 8        Shooter     0.130
# 1      Adventure     0.090

# %%
df_nintendo.groupby("Genre", as_index = False) \
    .agg({"JP_Sales" : "mean"}).sort_values("JP_Sales", ascending=False)
# Out:
#            Genre  JP_Sales
# 7   Role-Playing  0.970952
# 4       Platform  0.922162
# 9     Simulation  0.844643
# 2       Fighting  0.830000
# 6         Racing  0.789730
# 10        Sports  0.652182
# 3           Misc  0.552500
# 5         Puzzle  0.501216
# 0         Action  0.373846
# 11      Strategy  0.337419
# 1      Adventure  0.257429
# 8        Shooter  0.251250

# %%
df_nintendo_FSPRS = df_nintendo.query("Genre in ('Fighting', 'Simulation', 'Platform', 'Racing', 'Sports')")

# %%
df_nintendo_FSPRS
# Out:
#         Rank                                          Name Platform    Year  \
# 0          1                                    Wii Sports      Wii  2006.0
# 1          2                             Super Mario Bros.      NES  1985.0
# 2          3                                Mario Kart Wii      Wii  2008.0
# 3          4                             Wii Sports Resort      Wii  2009.0
# 6          7                         New Super Mario Bros.       DS  2006.0
# ...      ...                                           ...      ...     ...
# 12123  12125                                  Mario Tennis      Wii  2010.0
# 12770  12772  Dance Dance Revolution: Mario Mix (JP sales)       GC  2005.0
# 14626  14629                                    Calcio Bit      GBA  2006.0
# 14968  14971                                Teddy Together      3DS  2016.0
# 15991  15994                       Donkey Kong Jungle Beat      Wii  2008.0
#
# ...

# %%
df_nintendo_FSPRS.groupby(["Genre", "Year"], as_index=[False, False]).sum().reset_index()
# Out:
#         Genre    Year   Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0    Fighting  1987.0   1114      2.80      0.65      1.87         0.10
# 1    Fighting  1993.0    851      0.52      0.16      1.29         0.03
# 2    Fighting  1995.0    423      2.26      0.72      0.12         0.10
# 3    Fighting  1996.0  10944      0.61      0.19      0.17         0.01
# 4    Fighting  1999.0    158      2.95      0.60      1.97         0.04
# ..        ...     ...    ...       ...       ...       ...          ...
# 109    Sports  2010.0  12908      0.90      0.51      0.63         0.14
# 110    Sports  2012.0  12243      0.26      0.29      0.44         0.05
# 111    Sports  2013.0   4942      0.78      0.46      0.34         0.12
# 112    Sports  2014.0   8947      0.34      0.28      0.21         0.06
# 113    Sports  2015.0   4402      0.13      0.16      0.13         0.03
#
#      Global_Sales
# 0            5.42
# 1            2.00
# 2            3.20
# 3            0.99
# ...

# %%
sns.lineplot(x = 'Year', y = 'Global_Sales', hue = 'Genre', data = df_nintendo_FSPRS)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
sns.set(
    font_scale = 2,
    style = "whitegrid",
    rc = {"figure.figsize" : (20,10)}
)

# %%
df = pd.read_csv("/mnt/HC_Volume_18315164/home-jupyter/jupyter-an-bogdanov/conversion.csv")

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# ...

# %%
df.xyz_campaign_id.nunique()
# Out:
# 3

# %%
df.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
df.Approved_Conversion.value_counts()
# Out:
# 0     559
# 1     403
# 2      86
# 3      35
# 4      24
# 6       7
# 5       7
# 8       5
# 10      4
# 7       4
# 9       3
# 14      2
# 21      1
# 17      1
# 13      1
# 12      1
# Name: Approved_Conversion, dtype: int64

# %%
df_impress = df.groupby("fb_campaign_id", as_index=False) \
    .agg({"Impressions" : "sum"})

# %%
df_impress
# Out:
#      fb_campaign_id  Impressions
# 0            103916         7350
# 1            103917        17861
# 2            103920          693
# 3            103928         8392
# 4            103929         1915
# ..              ...          ...
# 686          179977      1129773
# 687          179978       637549
# 688          179979       151531
# 689          179981       790253
# 690          179982       513161
#
# [691 rows x 2 columns]

# %%
df_impress["Impressions"] = np.log(df_impress.Impressions)

# %%
df_impress
# Out:
#      fb_campaign_id  Impressions
# 0            103916     8.902456
# 1            103917     9.790375
# 2            103920     6.541030
# 3            103928     9.035034
# 4            103929     7.557473
# ..              ...          ...
# 686          179977    13.937527
# 687          179978    13.365386
# 688          179979    11.928546
# 689          179981    13.580108
# 690          179982    13.148345
#
# [691 rows x 2 columns]

# %%
sns.distplot(df_impress, kde = False)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["ctr"] = df.Clicks / df.Impressions

# %%
df[["ad_id", "ctr"]].sort_values("ctr", ascending=False)
# Out:
#       ad_id       ctr
# 150  738637  0.001059
# 440  950224  0.000845
# 505  951779  0.000610
# 476  951202  0.000565
# 448  950537  0.000531
# ..      ...       ...
# 270  777166  0.000000
# 269  777131  0.000000
# 268  777130  0.000000
# 266  776935  0.000000
# 181  747879  0.000000
#
# [1143 rows x 2 columns]

# %%
df.query("xyz_campaign_id == 916")
# Out:
#      ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0   708746              916          103916  30-34      M        15
# 1   708749              916          103917  30-34      M        16
# 2   708771              916          103920  30-34      M        20
# 3   708815              916          103928  30-34      M        28
# 4   708818              916          103928  30-34      M        28
# 5   708820              916          103929  30-34      M        29
# 6   708889              916          103940  30-34      M        15
# 7   708895              916          103941  30-34      M        16
# 8   708953              916          103951  30-34      M        27
# 9   708958              916          103952  30-34      M        28
# 10  708979              916          103955  30-34      M        31
# 11  709023              916          103962  30-34      M         7
# 12  709038              916          103965  30-34      M        16
# ...

# %%
sns.distplot(df.query("xyz_campaign_id == 916").ctr, kde = False, bins=20)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["cpc"] = df.Spent / df.Clicks

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# ...

# %%
sns.distplot(df.cpc, kde = False, bins=20)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ss.iqr(df.cpc, nan_policy='omit').round(2)
# Out:
# 0.25

# %%
sns.distplot(df.query("gender == 'M'").cpc)
sns.distplot(df.query("gender == 'F'").cpc)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["convertion"] = df.Approved_Conversion / df.Clicks

# %%
df.query("ad_id == 1121814")
# Out:
#        ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 860  1121814             1178          144659  30-34      F        27
#
#      Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 860      2223278     421  612.300003                38                   13
#
#           ctr       cpc  convertion
# 860  0.000189  1.454394    0.030879

# %%
round(df.query("ad_id == 1121814").convertion*100, 2)
# Out:
# 860    3.09
# Name: convertion, dtype: float64
